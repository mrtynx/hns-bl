# %% [markdown]
# # **Posilňujúce učenie**
#  Je to typ strojového učenia, v ktorom sa agent učí robiť rozhodnutia na základe odmien alebo trestov za svoje konanie. Cieľom agenta je maximalizovat kumulatívnu odmenu tým, že sa naučí optimalne zasady, ktoré mapuju výsledky k rozhodnutiam.![image2.png](data:image/png;base64,...)

# %% [markdown]
# ### Terminológia
# **Prostredie(Enviroment)** V posilňujúcom učeni je prostredie označenie pre miesto kde náš agent preskúmava a uči sa. Ak by sme agenta učili hrať BlackJack, prostredím by bol hrací stol s kartami.
#
# **Agent(Agent)** Agent je entita, ktorá preskúmava prostredie, interaguje a robí rôzne akcie v prostredí. V príklade BlackJacku by agentom bol hráč.
#
# **Stav(State)** Agent je vždy v nejakom stave, ktorý nám hovorí o statuse agenta. Najčastejším príkladom stavu je poloha agenta v prostredí. Pohyb agenta bude meniť jeho stav.
#
# **Akcia(Action)** Každá interakcia medzi agentom a prostredím je považovaná za akciu. Akcia môže no nemusí zmeniť stav agenta. Aj nič nerobenie je považované za akciu. V prípade BlackJacku by to bolo neťahať dalšiu kartu.
#
# **Odmena(Reward)** Každá akcia, ktorú agent vykoná bude preňho znamenať odmenu určitej výšky(kladná alebo záporná). Cieľom nášho agenta je maximalizovať odmenu. Ak by náš agent v BlackJacku vyhral dostal by kladnú odmenu, naopak ak by prehral alebo potiahol viac kariet ako mal bude odmena negatívna.
#
#
# Najdôležitejšia čast posilňujúceho učenia je stanovenie ako odmeňovať agenta. To znamená, že by sme ho mali odmenovať adekvátne aby nakoniec dosiahol svoj cieľ.

# %% [markdown]
# ### Algoritmy posilňujúceho učenia, ktoré budeme používať
#
# DQN
#
# A2C
#
# SAC

# %% [markdown]
# # **1. Inštalácia knižnic a videa**

# %% [markdown]
# Najprv potrebujeme naistalovat potrebné kniznice trenovacieho prostredia, RL ucenia a videodispleja

# %%
# !pip install stable-baselines3[extra]
# !apt-get install ffmpeg freeglut3-dev xvfb  
# !apt-get update && apt-get install swig cmake
# !pip install box2d-py
# !pip install "stable-baselines3[extra]>=2.0.0a4"
# Out:
# Requirement already satisfied: stable-baselines3[extra] in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (2.2.1)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]) (1.25.2)
# Requirement already satisfied: torch>=1.13 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]) (2.0.1)
# Requirement already satisfied: cloudpickle in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pandas in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]) (1.5.3)
# Requirement already satisfied: matplotlib in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]) (3.7.2)
# Requirement already satisfied: opencv-python in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]) (4.8.1.78)
# Requirement already satisfied: pygame in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]) (2.5.2)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]) (2.14.0)
# Requirement already satisfied: psutil in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]) (5.9.0)
# Requirement already satisfied: tqdm in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]) (4.65.2)
# Requirement already satisfied: rich in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]) (13.7.0)
# Requirement already satisfied: shimmy[atari]~=1.3.0 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: pillow in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]) (9.4.0)
# Requirement already satisfied: autorom[accept-rom-license]~=0.6.1 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: click in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (8.1.7)
# Requirement already satisfied: requests in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (2.31.0)
# Requirement already satisfied: AutoROM.accept-rom-license in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (4.7.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (0.0.4)
# Requirement already satisfied: importlib-metadata>=4.8.0 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (6.8.0)
# Requirement already satisfied: ale-py~=0.8.1 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from shimmy[atari]~=1.3.0->stable-baselines3[extra]) (0.8.1)
# Requirement already satisfied: absl-py>=0.4 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.58.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.4.4)
# Requirement already satisfied: protobuf>=3.19.6 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (4.24.3)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (68.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.3.7)
# Requirement already satisfied: wheel>=0.26 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.38.4)
# Requirement already satisfied: filelock in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.12.4)
# Requirement already satisfied: sympy in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (1.11.1)
# Requirement already satisfied: networkx in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.1)
# Requirement already satisfied: jinja2 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from matplotlib->stable-baselines3[extra]) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from matplotlib->stable-baselines3[extra]) (5.2.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from pandas->stable-baselines3[extra]) (2023.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from rich->stable-baselines3[extra]) (2.16.1)
# Requirement already satisfied: colorama in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from tqdm->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: urllib3<2.0 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (1.26.16)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from importlib-metadata>=4.8.0->gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (3.16.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from sympy->torch>=1.13->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.2)
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.
# ^C
# Requirement already satisfied: box2d-py in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (2.3.5)
# Requirement already satisfied: stable-baselines3[extra]>=2.0.0a4 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (2.2.1)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (1.25.2)
# Requirement already satisfied: torch>=1.13 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (2.0.1)
# Requirement already satisfied: cloudpickle in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (3.0.0)
# Requirement already satisfied: pandas in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (1.5.3)
# Requirement already satisfied: matplotlib in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (3.7.2)
# Requirement already satisfied: opencv-python in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (4.8.1.78)
# Requirement already satisfied: pygame in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (2.5.2)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (2.14.0)
# Requirement already satisfied: psutil in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (5.9.0)
# Requirement already satisfied: tqdm in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (4.65.2)
# Requirement already satisfied: rich in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (13.7.0)
# Requirement already satisfied: shimmy[atari]~=1.3.0 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (1.3.0)
# Requirement already satisfied: pillow in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (9.4.0)
# Requirement already satisfied: autorom[accept-rom-license]~=0.6.1 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from stable-baselines3[extra]>=2.0.0a4) (0.6.1)
# Requirement already satisfied: click in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]>=2.0.0a4) (8.1.7)
# Requirement already satisfied: requests in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]>=2.0.0a4) (2.31.0)
# Requirement already satisfied: AutoROM.accept-rom-license in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]>=2.0.0a4) (0.6.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]>=2.0.0a4) (4.7.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]>=2.0.0a4) (0.0.4)
# Requirement already satisfied: importlib-metadata>=4.8.0 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]>=2.0.0a4) (6.8.0)
# Requirement already satisfied: ale-py~=0.8.1 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from shimmy[atari]~=1.3.0->stable-baselines3[extra]>=2.0.0a4) (0.8.1)
# Requirement already satisfied: absl-py>=0.4 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (2.0.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.58.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.4.4)
# Requirement already satisfied: protobuf>=3.19.6 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (4.24.3)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (68.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (2.3.7)
# Requirement already satisfied: wheel>=0.26 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (0.38.4)
# Requirement already satisfied: filelock in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a4) (3.12.4)
# Requirement already satisfied: sympy in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a4) (1.11.1)
# Requirement already satisfied: networkx in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a4) (3.1)
# Requirement already satisfied: jinja2 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from torch>=1.13->stable-baselines3[extra]>=2.0.0a4) (3.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from matplotlib->stable-baselines3[extra]>=2.0.0a4) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from matplotlib->stable-baselines3[extra]>=2.0.0a4) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from matplotlib->stable-baselines3[extra]>=2.0.0a4) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from matplotlib->stable-baselines3[extra]>=2.0.0a4) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from matplotlib->stable-baselines3[extra]>=2.0.0a4) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from matplotlib->stable-baselines3[extra]>=2.0.0a4) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from matplotlib->stable-baselines3[extra]>=2.0.0a4) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from matplotlib->stable-baselines3[extra]>=2.0.0a4) (5.2.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from pandas->stable-baselines3[extra]>=2.0.0a4) (2023.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (2.16.1)
# Requirement already satisfied: colorama in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from tqdm->stable-baselines3[extra]>=2.0.0a4) (0.4.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (4.9)
# Requirement already satisfied: urllib3<2.0 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.26.16)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from importlib-metadata>=4.8.0->gymnasium<0.30,>=0.28.1->stable-baselines3[extra]>=2.0.0a4) (3.16.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a4) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3[extra]>=2.0.0a4) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]>=2.0.0a4) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]>=2.0.0a4) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]>=2.0.0a4) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from sympy->torch>=1.13->stable-baselines3[extra]>=2.0.0a4) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\marti\miniconda3\envs\win-torch\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.2.2)

# %% [markdown]
# Na zobrazenie vyuzijeme falosny displej

# %%
import os
os.system("Xvfb :1 -screen 0 1024x768x24 &")
os.environ['DISPLAY'] = ':1'

# %%
import base64
from pathlib import Path

from IPython import display as ipythondisplay


def show_videos(video_path="", prefix=""):
    """
    Taken from https://github.com/eleurent/highway-env

    :param video_path: (str) Path to the folder containing videos
    :param prefix: (str) Filter the video, showing only the only starting with this prefix
    """
    html = []
    for mp4 in Path(video_path).glob("{}*.mp4".format(prefix)):
        video_b64 = base64.b64encode(mp4.read_bytes())
        html.append(
            """<video alt="{}" autoplay 
                    loop controls style="height: 400px;">
                    <source src="data:video/mp4;base64,{}" type="video/mp4" />
                </video>""".format(
                mp4, video_b64.decode("ascii")
            )
        )
    ipythondisplay.display(ipythondisplay.HTML(data="<br>".join(html)))

# %% [markdown]
# # **2. Import prostredia, RL agenta, monitoru ...**

# %% [markdown]
# Vyuzijeme prostredie Gymnasium od OpenAI, numpy a z stable baselines importujeme deep-Q-network umelu neuronovu siet.
#
# https://gymnasium.farama.org/  dokumentacia pre prostredie v ktorom trenujeme agentov
#
# https://stable-baselines3.readthedocs.io/en/master/ dokumentacia pre RL algoritmy

# %%
import gymnasium as gym
import numpy as np
import tempfile
import os

from stable_baselines3.common.results_plotter import load_results, ts2xy          # import funkci na vyzobrazenie vysledkov
from stable_baselines3.common.noise import NormalActionNoise                      # import dacoho
from stable_baselines3.common.callbacks import BaseCallback                       # import callback funkcie
from stable_baselines3.common.monitor import Monitor                              # na zobrazenie treningoveho progresu
from stable_baselines3.common.callbacks import CheckpointCallback                 # callback pocas treningu
from stable_baselines3 import DQN                                                 # import DQN algoritmu
from stable_baselines3 import SAC                                                 # import SAC algoritmu
from stable_baselines3 import A2C                                                 # import A2C algoritmu

# %% [markdown]
# Vytvoríme si Callback funkciu, ktorá bude ukladať model

# %%
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """

    def __init__(self, check_freq: int, log_dir: str, verbose=1):
        super().__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, "best_model")
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

            # Retrieve training reward
            x, y = ts2xy(load_results(self.log_dir), "timesteps")
            if len(x) > 0:
                # Mean training reward over the last 100 episodes
                mean_reward = np.mean(y[-100:])
                if self.verbose > 0:
                    print(f"Num timesteps: {self.num_timesteps}")
                    print(
                        f"Best mean reward: {self.best_mean_reward:.2f} - Last mean reward per episode: {mean_reward:.2f}"
                    )

                # New best model, you could save the agent here
                if mean_reward > self.best_mean_reward:
                    self.best_mean_reward = mean_reward
                    # Example for saving best model
                    if self.verbose > 0:
                        print(f"Saving new best model to {self.save_path}.zip")
                    self.model.save(self.save_path)

        return True

# %% [markdown]
# # **3. Vytvorenie Gym prostredia a iniciacia agenta**

# %% [markdown]
# Pre LunarLander sme si vybrali DQN algoritmus s MLP taktiku pretoze nase prostredie ma vektory a nie obrazky, mozeme to vsak zmenit na SAC alebo A2C algoritmus

# %%
log_dir = "/tmp/gym/"
os.makedirs(log_dir, exist_ok=True)          # docasny priecinok na ukladanie progresu treningu

env = gym.make('LunarLander-v2')             # vytvorenie prostredia LunarLander(da sa zmenit na iné napr CarRacing-v2)
env = Monitor(env, log_dir)                  # pridanie triedy Monitor do prostredia a virtualneho priecinku, tu sa ukladaju logy 

model = DQN(                      # mozeme zmenit na SAC alebo A2C
    "MlpPolicy",                  # typ neuronovej siete
    env,                          # typ prostredia
    verbose=1,                    # print progresu do konzoly
    #exploration_final_eps=0.1,   # finalna hodnota šance nahodnych akcii namiesto doporučených akcií 
    #target_update_interval=250,  # frekvencia updatu neuronovej siete
    #learning_rate = 0.5          # rýchlosť učenia v intervale <0,1>
    #buffer_size = 1000           # veľkosť buffera na ukladanie skúseností
    #batch_size = 8               # veľkosť vzorky ktorá sa načíta z buffera

)                                  
"""
Tieto zakomentovane hyperparametre nemusíme nastavovať pretože sa nastavia automaticky, no možeme ručne menit ich hodnoty
"""
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.
# '\nTieto zakomentovane hyperparametre nemusíme nastavovať pretože sa nastavia automaticky, no možeme ručne menit ich hodnoty\n'

# %% [markdown]
# Nacitame si pomocnu funkciu, ktora bude hodnotit agenta bez treningu v prostredi

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# Zhodnotime vykon agenta bez treningu v prostredi

# %%
# Separacia prostredia na evaluaciu
eval_env = gym.make("LunarLander-v2")

# Nahodny agent bez treningu
mean_reward, std_reward = evaluate_policy(
    model,
    eval_env,
    n_eval_episodes=10,
    deterministic=True,
)
# Vypis AVERAGE odmeny agenta bez treningu
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# c:\Users\marti\miniconda3\envs\win-torch\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward=-605.24 +/- 133.5600960863808

# %% [markdown]
# Nahrame agenta bez treningu do videa

# %%
from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv


def record_video(env_id, model, video_length=500, prefix="", video_folder="videos/"):
    """
    :param env_id: (str)
    :param model: (RL model)
    :param video_length: (int)
    :param prefix: (str)
    :param video_folder: (str)
    """
    eval_env = DummyVecEnv([lambda: gym.make(env_id, render_mode="rgb_array")])
    # Start the video at step=0 and record 500 steps
    eval_env = VecVideoRecorder(
        eval_env,
        video_folder=video_folder,
        record_video_trigger=lambda step: step == 0,
        video_length=video_length,
        name_prefix=prefix,
    )

    obs = eval_env.reset()
    for _ in range(video_length):
        action, _ = model.predict(obs)
        obs, _, _, _ = eval_env.step(action)

   
    eval_env.close()

# %%
record_video("LunarLander-v2", model, video_length=600, prefix="noTraining-LunarLander-v2")
# Out:
# Saving video to c:\FEI\HNS\hns-bl\videos\noTraining-LunarLander-v2-step-0-to-step-600.mp4
# Moviepy - Building video c:\FEI\HNS\hns-bl\videos\noTraining-LunarLander-v2-step-0-to-step-600.mp4.
# Moviepy - Writing video c:\FEI\HNS\hns-bl\videos\noTraining-LunarLander-v2-step-0-to-step-600.mp4
# Moviepy - Done !
# Moviepy - video ready c:\FEI\HNS\hns-bl\videos\noTraining-LunarLander-v2-step-0-to-step-600.mp4

# %%
show_videos("videos", prefix="noTraining")
# Out:
# <video alt="videos\noTraining-LunarLander-v2-step-0-to-step-600.mp4" autoplay
#                     loop controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                 </video>

# %% [markdown]
# # **4. Tréning agenta**

# %%
import matplotlib.pyplot as plt
import pandas as pd 

callback = SaveOnBestTrainingRewardCallback(check_freq=1000, log_dir=log_dir)

# Trening, trva dlhsie 
model.learn(total_timesteps=int(1e5),callback=callback)

# ulozime agenta ako dqn_lunar 
model.save("dqn_lunar")

# Vymazeme aby sme mohli loadovat neskor
del model
# Out:
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | -114     |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 12663    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 426      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -122     |
# |    exploration_rate | 0.924    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 13432    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 801      |
# ----------------------------------
# Num timesteps: 1000
# Best mean reward: -inf - Last mean reward per episode: -50.53
# Saving new best model to tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.4     |
# |    ep_rew_mean      | -115     |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 11553    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1193     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.8     |
# |    ep_rew_mean      | -122     |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 12037    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1580     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.6     |
# |    ep_rew_mean      | -119     |
# |    exploration_rate | 0.811    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 12276    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1992     |
# ----------------------------------
# Num timesteps: 2000
# Best mean reward: -50.53 - Last mean reward per episode: -53.94
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | -150     |
# |    exploration_rate | 0.766    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 11576    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2464     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | -151     |
# |    exploration_rate | 0.725    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 11759    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2891     |
# ----------------------------------
# Num timesteps: 3000
# Best mean reward: -50.53 - Last mean reward per episode: -69.59
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -151     |
# |    exploration_rate | 0.69     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 11234    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3262     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -164     |
# |    exploration_rate | 0.652    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 11482    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3667     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.8     |
# |    ep_rew_mean      | -163     |
# |    exploration_rate | 0.625    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 11537    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3950     |
# ----------------------------------
# Num timesteps: 4000
# Best mean reward: -50.53 - Last mean reward per episode: -85.19
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | -162     |
# |    exploration_rate | 0.582    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 11168    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4400     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.539    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 11284    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4852     |
# ----------------------------------
# Num timesteps: 5000
# Best mean reward: -50.53 - Last mean reward per episode: -92.68
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | -162     |
# |    exploration_rate | 0.503    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 11149    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5229     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.2     |
# |    ep_rew_mean      | -164     |
# |    exploration_rate | 0.472    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 11192    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5558     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99       |
# |    ep_rew_mean      | -161     |
# |    exploration_rate | 0.436    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 11280    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5940     |
# ----------------------------------
# Num timesteps: 6000
# Best mean reward: -50.53 - Last mean reward per episode: -106.94
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.7     |
# |    ep_rew_mean      | -164     |
# |    exploration_rate | 0.4      |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 11190    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6318     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.7     |
# |    ep_rew_mean      | -158     |
# |    exploration_rate | 0.363    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 11234    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6709     |
# ----------------------------------
# Num timesteps: 7000
# Best mean reward: -50.53 - Last mean reward per episode: -117.84
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.3     |
# |    ep_rew_mean      | -155     |
# |    exploration_rate | 0.328    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 11035    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7076     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.2     |
# |    ep_rew_mean      | -155     |
# |    exploration_rate | 0.299    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 11117    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7384     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.2     |
# |    ep_rew_mean      | -161     |
# |    exploration_rate | 0.261    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 11188    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7774     |
# ----------------------------------
# Num timesteps: 8000
# Best mean reward: -50.53 - Last mean reward per episode: -135.70
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.8     |
# |    ep_rew_mean      | -161     |
# |    exploration_rate | 0.227    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 11008    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8133     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.2     |
# |    ep_rew_mean      | -160     |
# |    exploration_rate | 0.196    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 11049    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8462     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.3     |
# |    ep_rew_mean      | -160     |
# |    exploration_rate | 0.158    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 11086    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8863     |
# ----------------------------------
# Num timesteps: 9000
# Best mean reward: -50.53 - Last mean reward per episode: -153.15
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.1     |
# |    ep_rew_mean      | -162     |
# |    exploration_rate | 0.123    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 10898    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9229     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.4     |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.0846   |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 10957    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9636     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.2     |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.0552   |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 10949    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9945     |
# ----------------------------------
# Num timesteps: 10000
# Best mean reward: -50.53 - Last mean reward per episode: -166.04
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.7     |
# |    ep_rew_mean      | -166     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 10808    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10271    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.4     |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 10868    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10730    |
# ----------------------------------
# Num timesteps: 11000
# Best mean reward: -50.53 - Last mean reward per episode: -168.35
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.4     |
# |    ep_rew_mean      | -168     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 10780    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11016    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.6     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 10844    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11450    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -164     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 10872    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11763    |
# ----------------------------------
# Num timesteps: 12000
# Best mean reward: -50.53 - Last mean reward per episode: -164.29
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.9     |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 10782    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12178    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.5     |
# |    ep_rew_mean      | -165     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 10793    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12515    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.5     |
# |    ep_rew_mean      | -161     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 10839    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12922    |
# ----------------------------------
# Num timesteps: 13000
# Best mean reward: -50.53 - Last mean reward per episode: -160.89
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94       |
# |    ep_rew_mean      | -161     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 10777    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13351    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.2     |
# |    ep_rew_mean      | -162     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 10809    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13715    |
# ----------------------------------
# Num timesteps: 14000
# Best mean reward: -50.53 - Last mean reward per episode: -158.47
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -159     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 10613    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 14024    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.6     |
# |    ep_rew_mean      | -163     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 10676    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 14386    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -163     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 10753    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 14768    |
# ----------------------------------
# Num timesteps: 15000
# Best mean reward: -50.53 - Last mean reward per episode: -167.27
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 10707    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 15205    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 10718    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 15531    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.5     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 10757    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 15954    |
# ----------------------------------
# Num timesteps: 16000
# Best mean reward: -50.53 - Last mean reward per episode: -172.66
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -181     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 10648    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16309    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.9     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 10678    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16675    |
# ----------------------------------
# Num timesteps: 17000
# Best mean reward: -50.53 - Last mean reward per episode: -177.17
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.7     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 10589    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17040    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.1     |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 10614    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17442    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.9     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 10638    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17752    |
# ----------------------------------
# Num timesteps: 18000
# Best mean reward: -50.53 - Last mean reward per episode: -181.60
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.8     |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 10550    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18045    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 10573    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18361    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.6     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 10601    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18696    |
# ----------------------------------
# Num timesteps: 19000
# Best mean reward: -50.53 - Last mean reward per episode: -179.80
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 10539    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19014    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 10572    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19386    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.1     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 10612    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19740    |
# ----------------------------------
# Num timesteps: 20000
# Best mean reward: -50.53 - Last mean reward per episode: -184.18
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 10553    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 20153    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 10596    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 20573    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 10624    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 20894    |
# ----------------------------------
# Num timesteps: 21000
# Best mean reward: -50.53 - Last mean reward per episode: -189.69
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.1     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 10570    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 21290    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 10595    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 21660    |
# ----------------------------------
# Num timesteps: 22000
# Best mean reward: -50.53 - Last mean reward per episode: -195.81
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -198     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 10548    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 22065    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 10565    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 22481    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 10595    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 22791    |
# ----------------------------------
# Num timesteps: 23000
# Best mean reward: -50.53 - Last mean reward per episode: -194.94
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.6     |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 10555    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 23180    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.8     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 10593    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 23571    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.8     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 10621    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 23952    |
# ----------------------------------
# Num timesteps: 24000
# Best mean reward: -50.53 - Last mean reward per episode: -187.77
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.9     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 10554    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 24294    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 10566    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 24608    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.4     |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 10591    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 24993    |
# ----------------------------------
# Num timesteps: 25000
# Best mean reward: -50.53 - Last mean reward per episode: -183.35
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 10540    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 25388    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.4     |
# |    ep_rew_mean      | -177     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 10559    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 25719    |
# ----------------------------------
# Num timesteps: 26000
# Best mean reward: -50.53 - Last mean reward per episode: -177.93
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.6     |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 10530    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 26101    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 10552    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 26467    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91       |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 10575    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 26853    |
# ----------------------------------
# Num timesteps: 27000
# Best mean reward: -50.53 - Last mean reward per episode: -172.53
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -172     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 10547    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 27218    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 10558    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 27515    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 10574    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 27905    |
# ----------------------------------
# Num timesteps: 28000
# Best mean reward: -50.53 - Last mean reward per episode: -174.24
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.9     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 10534    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 28302    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.1     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 10540    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 28600    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.8     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 10553    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 28920    |
# ----------------------------------
# Num timesteps: 29000
# Best mean reward: -50.53 - Last mean reward per episode: -181.63
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.8     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 10524    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 29334    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 10546    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 29645    |
# ----------------------------------
# Num timesteps: 30000
# Best mean reward: -50.53 - Last mean reward per episode: -175.83
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.3     |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 10482    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 30020    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.1     |
# |    ep_rew_mean      | -173     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 10508    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 30399    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.1     |
# |    ep_rew_mean      | -171     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 10538    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 30767    |
# ----------------------------------
# Num timesteps: 31000
# Best mean reward: -50.53 - Last mean reward per episode: -170.09
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 10496    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 31149    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | -164     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 10515    |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 31528    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | -167     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 10532    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 31841    |
# ----------------------------------
# Num timesteps: 32000
# Best mean reward: -50.53 - Last mean reward per episode: -167.07
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.5     |
# |    ep_rew_mean      | -169     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 10496    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 32225    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -170     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 10521    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 32594    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 10542    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 32973    |
# ----------------------------------
# Num timesteps: 33000
# Best mean reward: -50.53 - Last mean reward per episode: -176.41
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.9     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 10492    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 33386    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.8     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 10511    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 33791    |
# ----------------------------------
# Num timesteps: 34000
# Best mean reward: -50.53 - Last mean reward per episode: -183.16
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.9     |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 10474    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 34079    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.2     |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 10494    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 34406    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.6     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 10509    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 34780    |
# ----------------------------------
# Num timesteps: 35000
# Best mean reward: -50.53 - Last mean reward per episode: -180.37
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -183     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 10463    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 35184    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 10483    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 35588    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 10503    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 35931    |
# ----------------------------------
# Num timesteps: 36000
# Best mean reward: -50.53 - Last mean reward per episode: -192.94
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.5     |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 10471    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 36364    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 10484    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 36686    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 10493    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 36984    |
# ----------------------------------
# Num timesteps: 37000
# Best mean reward: -50.53 - Last mean reward per episode: -180.40
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.7     |
# |    ep_rew_mean      | -174     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 10466    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 37370    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.2     |
# |    ep_rew_mean      | -178     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 10484    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 37722    |
# ----------------------------------
# Num timesteps: 38000
# Best mean reward: -50.53 - Last mean reward per episode: -178.39
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.8     |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 10455    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 38100    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 10472    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 38529    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.5     |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 10488    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 38894    |
# ----------------------------------
# Num timesteps: 39000
# Best mean reward: -50.53 - Last mean reward per episode: -182.55
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.5     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 10468    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 39271    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92       |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 10480    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 39598    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.8     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 10490    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 39942    |
# ----------------------------------
# Num timesteps: 40000
# Best mean reward: -50.53 - Last mean reward per episode: -183.79
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.6     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 10468    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 40411    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.6     |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 10485    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 40791    |
# ----------------------------------
# Num timesteps: 41000
# Best mean reward: -50.53 - Last mean reward per episode: -189.30
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.5     |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 10456    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 41186    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93       |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 10469    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 41530    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.5     |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 10480    |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 41849    |
# ----------------------------------
# Num timesteps: 42000
# Best mean reward: -50.53 - Last mean reward per episode: -194.22
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | -191     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 10443    |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 42208    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.4     |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 10449    |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 42525    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# ...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 181      |
# |    ep_rew_mean      | -151     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 3604     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 61377    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.13     |
# |    n_updates        | 71503    |
# ----------------------------------
# Num timesteps: 62000
# Best mean reward: -50.53 - Last mean reward per episode: -149.39
# Num timesteps: 63000
# Best mean reward: -50.53 - Last mean reward per episode: -148.25
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 203      |
# |    ep_rew_mean      | -147     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 3254     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 63945    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.268    |
# |    n_updates        | 72145    |
# ----------------------------------
# Num timesteps: 64000
# Best mean reward: -50.53 - Last mean reward per episode: -146.61
# Num timesteps: 65000
# Best mean reward: -50.53 - Last mean reward per episode: -144.53
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 216      |
# |    ep_rew_mean      | -135     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 3071     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 65618    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.471    |
# |    n_updates        | 72563    |
# ----------------------------------
# Num timesteps: 66000
# Best mean reward: -50.53 - Last mean reward per episode: -134.94
# Num timesteps: 67000
# Best mean reward: -50.53 - Last mean reward per episode: -133.66
# Num timesteps: 68000
# Best mean reward: -50.53 - Last mean reward per episode: -129.01
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 237      |
# |    ep_rew_mean      | -123     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 2856     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 68020    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.349    |
# |    n_updates        | 73163    |
# ----------------------------------
# Num timesteps: 69000
# Best mean reward: -50.53 - Last mean reward per episode: -118.46
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 251      |
# |    ep_rew_mean      | -115     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 2728     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 69793    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.374    |
# |    n_updates        | 73607    |
# ----------------------------------
# Num timesteps: 70000
# Best mean reward: -50.53 - Last mean reward per episode: -115.46
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 259      |
# |    ep_rew_mean      | -114     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 2638     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 70967    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.501    |
# |    n_updates        | 73900    |
# ----------------------------------
# Num timesteps: 71000
# Best mean reward: -50.53 - Last mean reward per episode: -114.31
# Num timesteps: 72000
# Best mean reward: -50.53 - Last mean reward per episode: -111.75
# Num timesteps: 73000
# Best mean reward: -50.53 - Last mean reward per episode: -107.35
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 277      |
# |    ep_rew_mean      | -107     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 2488     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 73126    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.26     |
# |    n_updates        | 74440    |
# ----------------------------------
# Num timesteps: 74000
# Best mean reward: -50.53 - Last mean reward per episode: -102.43
# Num timesteps: 75000
# Best mean reward: -50.53 - Last mean reward per episode: -96.80
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 294      |
# |    ep_rew_mean      | -94.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 2350     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 75193    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.867    |
# |    n_updates        | 74957    |
# ----------------------------------
# Num timesteps: 76000
# Best mean reward: -50.53 - Last mean reward per episode: -90.49
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 307      |
# |    ep_rew_mean      | -86.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 2273     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 76965    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.966    |
# |    n_updates        | 75400    |
# ----------------------------------
# Num timesteps: 77000
# Best mean reward: -50.53 - Last mean reward per episode: -86.30
# Num timesteps: 78000
# Best mean reward: -50.53 - Last mean reward per episode: -82.20
# Num timesteps: 79000
# Best mean reward: -50.53 - Last mean reward per episode: -79.61
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 325      |
# |    ep_rew_mean      | -76.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 2196     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 79051    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.456    |
# |    n_updates        | 75921    |
# ----------------------------------
# Num timesteps: 80000
# Best mean reward: -50.53 - Last mean reward per episode: -75.37
# Num timesteps: 81000
# Best mean reward: -50.53 - Last mean reward per episode: -72.64
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 344      |
# |    ep_rew_mean      | -66.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 2120     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 81308    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.398    |
# |    n_updates        | 76485    |
# ----------------------------------
# Num timesteps: 82000
# Best mean reward: -50.53 - Last mean reward per episode: -64.94
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 353      |
# |    ep_rew_mean      | -60.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 612      |
# |    fps              | 2086     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 82532    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.376    |
# |    n_updates        | 76791    |
# ----------------------------------
# Num timesteps: 83000
# Best mean reward: -50.53 - Last mean reward per episode: -57.56
# Num timesteps: 84000
# Best mean reward: -50.53 - Last mean reward per episode: -53.75
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 364      |
# |    ep_rew_mean      | -48.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 616      |
# |    fps              | 2045     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 84044    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.317    |
# |    n_updates        | 77169    |
# ----------------------------------
# Num timesteps: 85000
# Best mean reward: -50.53 - Last mean reward per episode: -43.14
# Saving new best model to tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 374      |
# |    ep_rew_mean      | -41.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 620      |
# |    fps              | 2011     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 85410    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.645    |
# |    n_updates        | 77511    |
# ----------------------------------
# Num timesteps: 86000
# Best mean reward: -43.14 - Last mean reward per episode: -37.00
# Saving new best model to tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 384      |
# |    ep_rew_mean      | -36.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 624      |
# |    fps              | 1979     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 86775    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.428    |
# |    n_updates        | 77852    |
# ----------------------------------
# Num timesteps: 87000
# Best mean reward: -37.00 - Last mean reward per episode: -36.09
# Saving new best model to tmp/gym/best_model.zip
# Num timesteps: 88000
# Best mean reward: -36.09 - Last mean reward per episode: -32.08
# Saving new best model to tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 396      |
# |    ep_rew_mean      | -31.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 628      |
# |    fps              | 1943     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 88282    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.226    |
# |    n_updates        | 78229    |
# ----------------------------------
# Num timesteps: 89000
# Best mean reward: -32.08 - Last mean reward per episode: -27.93
# Saving new best model to tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 404      |
# |    ep_rew_mean      | -26.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 632      |
# |    fps              | 1919     |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 89423    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.281    |
# |    n_updates        | 78514    |
# ----------------------------------
# Num timesteps: 90000
# Best mean reward: -27.93 - Last mean reward per episode: -24.51
# Saving new best model to tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 415      |
# |    ep_rew_mean      | -21.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 636      |
# |    fps              | 1892     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 90851    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.274    |
# |    n_updates        | 78871    |
# ----------------------------------
# Num timesteps: 91000
# Best mean reward: -24.51 - Last mean reward per episode: -21.56
# Saving new best model to tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 420      |
# |    ep_rew_mean      | -19.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 640      |
# |    fps              | 1876     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 91644    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.503    |
# |    n_updates        | 79069    |
# ----------------------------------
# Num timesteps: 92000
# Best mean reward: -21.56 - Last mean reward per episode: -18.83
# Saving new best model to tmp/gym/best_model.zip
# Num timesteps: 93000
# Best mean reward: -18.83 - Last mean reward per episode: -17.26
# Saving new best model to tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 430      |
# |    ep_rew_mean      | -16.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 644      |
# |    fps              | 1851     |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 93029    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.318    |
# |    n_updates        | 79416    |
# ----------------------------------
# Num timesteps: 94000
# Best mean reward: -17.26 - Last mean reward per episode: -15.43
# Saving new best model to tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 421      |
# |    ep_rew_mean      | -13.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 648      |
# |    fps              | 1828     |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 94444    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.204    |
# |    n_updates        | 79769    |
# ----------------------------------
# Num timesteps: 95000
# Best mean reward: -15.43 - Last mean reward per episode: -12.84
# Saving new best model to tmp/gym/best_model.zip
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 415      |
# |    ep_rew_mean      | -10.4    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 652      |
# |    fps              | 1805     |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 95895    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.584    |
# |    n_updates        | 80132    |
# ----------------------------------
# Num timesteps: 96000
# Best mean reward: -12.84 - Last mean reward per episode: -10.37
# Saving new best model to tmp/gym/best_model.zip
# Num timesteps: 97000
# Best mean reward: -10.37 - Last mean reward per episode: -13.72
# Num timesteps: 98000
# Best mean reward: -10.37 - Last mean reward per episode: -13.55
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 423      |
# |    ep_rew_mean      | -14      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 656      |
# |    fps              | 1766     |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 98577    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.785    |
# |    n_updates        | 80803    |
# ----------------------------------
# Num timesteps: 99000
# Best mean reward: -10.37 - Last mean reward per episode: -14.75
# Num timesteps: 100000
# Best mean reward: -10.37 - Last mean reward per episode: -14.92

# %% [markdown]
# Vykreslenie vysledkov učenia

# %%
def moving_average(values, window):
    """
    Uhladenie hodnot
    :param values: (numpy array)
    :param window: (int)
    :return: (numpy array)
    """
    weights = np.repeat(1.0, window) / window
    return np.convolve(values, weights, "same")

def plot_results( log_folder, title="Learning progress"):
    
    x1, y1 = ts2xy(load_results(log_dir), "timesteps")
    y1 = moving_average(y1, window=50)
    x1 = x1[len(x1) - len(y1) :]

    plt.plot(x1, y1, color='blue')
    plt.xlabel("Timesteps")
    plt.ylabel("Rewards")
    plt.show()

# %%
plot_results(log_dir)

# %% [markdown]
# # **5. Načítanie agenta**

# %% [markdown]
# Mozeme pridat dalsich inak natrenovanych agentov

# %%
model = DQN.load("dqn_lunar")

# %% [markdown]
# Evaluacia natrenovaneho agenta

# %%
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)

print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# c:\Users\marti\miniconda3\envs\win-torch\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward=-24.09 +/- 81.56654249228914

# %% [markdown]
# Nahrame video natrenovaneho agenta

# %%
def record_video(env_id, model, video_length=600, prefix="", video_folder="videos/"):
    """
    :param env_id: (str)
    :param model: (RL model)
    :param video_length: (int)
    :param prefix: (str)
    :param video_folder: (str)
    """
    eval_env = DummyVecEnv([lambda: gym.make(env_id, render_mode="rgb_array")])
    # Start the video at step=0 and record 500 steps
    eval_env = VecVideoRecorder(
        eval_env,
        video_folder=video_folder,
        record_video_trigger=lambda step: step == 0,
        video_length=video_length,
        name_prefix=prefix,
    )

    obs = eval_env.reset()
    for _ in range(video_length):
        action, _ = model.predict(obs)
        obs, _, _, _ = eval_env.step(action)

    # Close the video recorder
    eval_env.close()

# %%
record_video("LunarLander-v2", model, video_length=700, prefix="dqn-LunarLander-v2")
# Out:
# Saving video to c:\FEI\HNS\hns-bl\videos\dqn-LunarLander-v2-step-0-to-step-700.mp4
# Moviepy - Building video c:\FEI\HNS\hns-bl\videos\dqn-LunarLander-v2-step-0-to-step-700.mp4.
# Moviepy - Writing video c:\FEI\HNS\hns-bl\videos\dqn-LunarLander-v2-step-0-to-step-700.mp4
# Moviepy - Done !
# Moviepy - video ready c:\FEI\HNS\hns-bl\videos\dqn-LunarLander-v2-step-0-to-step-700.mp4

# %%
show_videos("videos", prefix="dqn")
# Out:
# <video alt="videos\dqn-LunarLander-v2-step-0-to-step-700.mp4" autoplay
#                     loop controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                 </video>
