# %% [markdown]
# ### **Projekt 1**

# %% [markdown]
# Pre najlepšie natrénovanú sieť z každého typu zobrazte proces trénovania.

# %%
import pickle
import numpy as np
import torch
from pretty_confusion_matrix import pp_matrix_from_data
from models_architecture import *
from matplotlib import pyplot as plt
from torchvision import utils

# %% [markdown]
# *Launch notebook for the respective network*

# %% [markdown]
# #### Resnet18

# %%
model = resnet18_architecture()
name = model.__class__.__name__
run='1'

# %% [markdown]
# #### Alexnet

# %%
model = alexnet_architecture()
name = model.__class__.__name__

# %% [markdown]
# #### Inception

# %%
model = inception_architecture()
name = model.__class__.__name__

# %% [markdown]
# #### Mobilenet

# %%
model = inception_architecture()
name = model.__class__.__name__

# %% [markdown]
# ### The function itself

# %%
path = 'trained_models'

#load model
#model.load_state_dict(torch.load(f"{path}/{name}/model.pt"))


#load training data
with open(f"{path}/{name}/{run}/train_metrics.pkl", "rb") as f:
    train_metrics = pickle.load(f)

plt.plot(train_metrics['acc_history'], label=name)
plt.title('Accuracy')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend()
plt.grid(True)
plt.show()

plt.plot(train_metrics['loss_history'], label=name)
plt.title('Loss (CrossEntropy)')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
plt.grid(True)
plt.show()
